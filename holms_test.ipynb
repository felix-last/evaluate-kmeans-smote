# %%
import imbtools.evaluation
from imbtools.evaluation import calculate_friedman_test
import yaml
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
from IPython.display import display
# %matplotlib inline
from statsmodels.stats.multitest import multipletests
with open("config.yml", 'r') as ymlfile:
    cfg = yaml.load(ymlfile)

# %%
path = cfg['results_dir']
session_id = 'current'
friedman_test_results = pd.read_csv('{}/{}/friedman_test_results.csv'.format(path, session_id), index_col=0)
friedman_test_results
# Out:
#    Classifier                Metric       p-value Significance
# 0         GBM     average_precision  3.753205e-27         True
# 1         GBM                    f1  9.362644e-36         True
# 2         GBM                    fn  1.869366e-37         True
# 3         GBM                    fp  1.550426e-47         True
# 4         GBM  geometric_mean_score  2.967734e-45         True
# 5         GBM               roc_auc  2.212488e-22         True
# 6         GBM                    tn  3.494651e-48         True
# 7         GBM                    tp  1.519474e-37         True
# 8         KNN     average_precision  8.280734e-27         True
# 9         KNN                    f1  6.510516e-30         True
# 10        KNN                    fn  4.806267e-60         True
# 11        KNN                    fp  4.448675e-48         True
# 12        KNN  geometric_mean_score  1.678436e-48         True
# 13        KNN               roc_auc  5.696049e-32         True
# 14        KNN                    tn  3.988913e-48         True
# 15        KNN                    tp  4.763184e-60         True
# 16         LR     average_precision  1.026239e-18         True
# 17         LR                    f1  1.386219e-28         True
# 18         LR                    fn  1.551257e-58         True
# 19         LR                    fp  5.793225e-38         True
# 20         LR  geometric_mean_score  1.343710e-36         True
# 21         LR               roc_auc  2.160405e-21         True
# 22         LR                    tn  2.722847e-38         True
# 23         LR                    tp  1.143746e-58         True

# %%
p_values = friedman_test_results['p-value']
p_values
multipletests(p_values, alpha=0.05, method='h')
# Out:
# (array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True], dtype=bool),
#  array([  1.87660227e-26,   8.42637925e-35,   2.05630281e-36,
#           2.48068168e-46,   4.45160094e-44,   6.63746425e-22,
#           6.63983602e-47,   1.82336865e-36,   3.31229343e-26,
#           4.55736155e-29,   1.14316405e-58,   7.56274697e-47,
#           3.35687160e-47,   4.55683916e-31,   7.18004280e-47,
#           1.14316405e-58,   1.02623873e-18,   8.31731117e-28,
#           3.25763958e-57,   7.53119236e-37,   1.34370967e-35,
#           4.32080924e-21,   3.81198565e-37,   2.51624076e-57]),
#  0.0021349383697015778,
#  0.0020833333333333333)
